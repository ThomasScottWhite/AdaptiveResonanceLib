# %%
def cluster_blobs():


if __name__ == "__main__":
    cluster_blobs()
# Out:
#   Cell In[2], line 4
#     if __name__ == "__main__":
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# # Relevant Papers
# NA

# %% [markdown]
# # Import Necessary Libraries

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

from artlib import iCVIFuzzyART

# %% [markdown]
# # Dataset Generation
#
# To demostrate ICVI_ART we use `sklearn` to generate a dataset consisting of 150 input vectors, each of length 2, with 3 centers.

# %%
data, target = make_blobs(n_samples=150, centers=3, cluster_std=0.50, random_state=0, shuffle=False)
print("Data has shape:", data.shape)
# Out:
# Data has shape: (150, 2)

# %% [markdown]
# ## Clustering with ICVIART
#
# In this example we initalize the ICVIFuzzyART model by providing it with the following parameters
# - `rho`: The vigilance parameter, controlling the level of similarity required for vectors to belong to the same cluster.
# - `alpha`: A parameter that controls noise suppression, helping to handle noisy data more effectively.
# - `beta`: The learning rate, which influences the speed of adaptation and category refinement.
# - `validity`: the cluster validity index being used.
#
# We prepare the data for input into the iCVIFuzzyART model using the `prepare_data` method
#
# After the clustering process, we can visualize the clusters using the `visualize` method.

# %%
params = {
    "rho": 0.0,
    "alpha": 0.0,
    "beta": 1.0,
    "validity": iCVIFuzzyART.CALINSKIHARABASZ
}
cls = iCVIFuzzyART(**params)

X = cls.prepare_data(data)
print("Prepared data has shape:", X.shape)

y = cls.fit_predict(X)

print(f"{cls.n_clusters} clusters found")

cls.visualize(X, y)
plt.show()
# Out:
# {'rho': 0.7, 'alpha': 0.0, 'beta': 1.0, 'validity': 1}
# Prepared data has shape: (150, 4)
# 10 clusters found
